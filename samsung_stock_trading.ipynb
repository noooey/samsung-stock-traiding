# %%
pip install -U finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.31-py3-none-any.whl (17 kB)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.63.0)
# Collecting requests-file
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (1.3.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.2.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (1.21.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2.10)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.31 requests-file-1.5.1

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd 'drive/MyDrive/BOAZ/분석/미니프로젝트'
# Out:
# /content/drive/MyDrive/BOAZ/분석/미니프로젝트

# %%
import pandas as pd
import numpy as np
import os
import FinanceDataReader as fdr

from sklearn.linear_model import LinearRegression
from tqdm import tqdm


import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import random
# %matplotlib inline

# %%
stock_list = pd.read_csv('Stock_List.csv')

stock_list['종목코드'] = stock_list['종목코드'].apply(lambda x : str(x).zfill(6))
stock_list
# Out:
#           종목명    종목코드    상장시장
# 0        삼성전자  005930   KOSPI
# 1      SK하이닉스  000660   KOSPI
# 2       NAVER  035420   KOSPI
# 3         카카오  035720   KOSPI
# 4    삼성바이오로직스  207940   KOSPI
# ..        ...     ...     ...
# 365      맘스터치  220630  KOSDAQ
# 366        다날  064260  KOSDAQ
# 367   제이시스메디칼  287410  KOSDAQ
# 368   크리스에프앤씨  110790  KOSDAQ
# 369     쎄트렉아이  099320  KOSDAQ
#
# [370 rows x 3 columns]

# %%
#상장폐지된 녹십자셀제거
indexdelete=stock_list[stock_list['종목코드']=='031390'].index
stock_list=stock_list.drop(indexdelete)
stock_list=stock_list.reset_index(drop=True)
stock_list
# Out:
#           종목명    종목코드    상장시장
# 0        삼성전자  005930   KOSPI
# 1      SK하이닉스  000660   KOSPI
# 2       NAVER  035420   KOSPI
# 3         카카오  035720   KOSPI
# 4    삼성바이오로직스  207940   KOSPI
# ..        ...     ...     ...
# 364      맘스터치  220630  KOSDAQ
# 365        다날  064260  KOSDAQ
# 366   제이시스메디칼  287410  KOSDAQ
# 367   크리스에프앤씨  110790  KOSDAQ
# 368     쎄트렉아이  099320  KOSDAQ
#
# [369 rows x 3 columns]

# %%
start_date = '20200520' #시작 날짜 지정해주기
end_date = '20220218' #끝나는 날짜 지정해주기

start_weekday = pd.to_datetime(start_date).weekday()
max_weeknum = pd.to_datetime(end_date).strftime('%V')
Business_days = pd.DataFrame(pd.date_range(start_date,end_date,freq='B'), columns = ['Date']) 

print(f'WEEKDAY of "start_date" : {start_weekday}')
print(f'NUM of WEEKS to "end_date" : {max_weeknum}')
print(f'HOW MANY "Business_days" : {Business_days.shape}',)
# Out:
# WEEKDAY of "start_date" : 2
# NUM of WEEKS to "end_date" : 07
# HOW MANY "Business_days" : (458, 1)

# %%
#EDA용 삼성전자 데이터셋
start_date = '20200528' #시작 날짜 지정해주기
end_date = '20220218' #끝나는 날짜 지정해주기
samsungstock = fdr.DataReader('005930', start = start_date, end = end_date)[['Close','Open','High','Low','Volume','Change']] 
samsungstock['High-Low']=samsungstock['High']-samsungstock['Low'] #고가-저가 변수 추가
samsungstock['Close-Open']=samsungstock['Close']-samsungstock['Open'] #종가-시가 변수 추가

exchange=fdr.DataReader('USD/KRW', start = start_date, end = end_date)[['Close']] 
exchange.columns=['exchange']
kospi=fdr.DataReader('KS11', start = start_date, end = end_date)[['Close']] 
kospi.columns=['kospi']
kosdaq=fdr.DataReader('KQ11', start = start_date, end = end_date)[['Close']] 
kosdaq.columns=['kosdaq']
dow=fdr.DataReader('DJI', start = start_date, end = end_date)[['Close']] 
dow.columns=['dow']
nasdaq=fdr.DataReader('IXIC',start = start_date, end = end_date)[['Close']] 
nasdaq.columns=['nasdaq']
sp500=fdr.DataReader('US500', start = start_date, end = end_date)[['Close']] 
sp500.columns=['sp500']

newvariable = pd.concat([samsungstock,exchange,kospi,kosdaq,dow,nasdaq,sp500],axis=1, join='outer')
newvariable=newvariable.reset_index()

# %% [markdown]
# 미국 지수 하루 씩 미뤄주고 null값 채워서 데이터셋 다시 만들기 ▼

# %%
dow_nan = newvariable[newvariable['dow'].isnull()].index
nasdaq_nan = newvariable[newvariable['nasdaq'].isnull()].index
sp500_nan = newvariable[newvariable['sp500'].isnull()].index

# %%
for i in dow_nan:
    for j in range(6,12):
        n = newvariable.iloc[i-1,-j]
        newvariable.iloc[i,-j] = n

# %%
for i in nasdaq_nan:
    for j in range(6,12):
        n = newvariable.iloc[i-1,-j]
        newvariable.iloc[i,-j] = n

# %%
for i in sp500_nan:
    for j in range(6,12):
        n = newvariable.iloc[i-1,-j]
        newvariable.iloc[i,-j] = n

# %%
newvariable[['dow','nasdaq','sp500']] = newvariable[['dow','nasdaq','sp500']].shift(1)
newvariable.isnull().sum()
# Out:
# Date           0
# Close         23
# Open          23
# High          23
# Low           23
# Volume        23
# Change        23
# High-Low      23
# Close-Open    23
# exchange       0
# kospi         23
# kosdaq        23
# dow           15
# nasdaq        15
# sp500         15
# dtype: int64

# %%
Close_nan = newvariable[newvariable['Close'].isnull()].index
Open_nan = newvariable[newvariable['Open'].isnull()].index
High_nan = newvariable[newvariable['High'].isnull()].index
Low_nan = newvariable[newvariable['Low'].isnull()].index
Volume_nan = newvariable[newvariable['Volume'].isnull()].index
Change_nan = newvariable[newvariable['Change'].isnull()].index
High_Low_nan = newvariable[newvariable['High-Low'].isnull()].index
kospi_nan = newvariable[newvariable['kospi'].isnull()].index
kosdaq_nan = newvariable[newvariable['kosdaq'].isnull()].index

# %%
nan_list = set(Close_nan.to_list() + Open_nan.to_list() + High_nan.to_list() +
               Low_nan.to_list() + Volume_nan.to_list() + Change_nan.to_list() + High_Low_nan.to_list() + 
               kospi_nan.to_list() + kosdaq_nan.to_list())

# %%
newvariable.drop(nan_list, inplace=True)

# %%
newvariable.drop(0, axis=0, inplace=True)

# %%
newvariable.isnull().sum()
# Out:
# Date           0
# Close          0
# Open           0
# High           0
# Low            0
# Volume         0
# Change         0
# High-Low       0
# Close-Open     0
# exchange       0
# kospi          0
# kosdaq         0
# dow           14
# nasdaq        14
# sp500         14
# dtype: int64

# %%
newvariable_a = newvariable.interpolate("ffill") #ffill=이전값으로 채워주기(?)
newvariable_a.isnull().sum()
# Out:
# Date          0
# Close         0
# Open          0
# High          0
# Low           0
# Volume        0
# Change        0
# High-Low      0
# Close-Open    0
# exchange      0
# kospi         0
# kosdaq        0
# dow           0
# nasdaq        0
# sp500         0
# dtype: int64

# %%
newvariable_a=newvariable_a.reset_index(drop=True) # index (0~354)순서대로 재설정
newvariable_a
# Out:
#           Date    Close     Open     High      Low      Volume    Change  \
# 0   2020-05-29  50700.0  50000.0  50700.0  49700.0  27596961.0  0.005952
# 1   2020-06-01  51200.0  50800.0  51200.0  50600.0  16949183.0  0.009862
# 2   2020-06-02  51400.0  51000.0  51500.0  50800.0  14247933.0  0.003906
# 3   2020-06-03  54500.0  51800.0  55000.0  51700.0  49257814.0  0.060311
# 4   2020-06-04  54600.0  55800.0  57000.0  54600.0  40220334.0  0.001835
# ..         ...      ...      ...      ...      ...         ...       ...
# 422 2022-02-14  73700.0  74400.0  74500.0  73100.0  13993255.0 -0.016021
# 423 2022-02-15  73700.0  74100.0  74200.0  73100.0   9320365.0  0.000000
# 424 2022-02-16  74800.0  74600.0  74900.0  74200.0  10767386.0  0.014925
# 425 2022-02-17  75000.0  75000.0  75600.0  74500.0  13605382.0  0.002674
# 426 2022-02-18  74300.0  74600.0  74800.0  73700.0  10122226.0 -0.009333
#
#      High-Low  Close-Open  exchange    kospi  kosdaq       dow    nasdaq  \
# 0      1000.0       700.0   1231.49  2029.60  713.68  25400.64   9368.99
# 1       600.0       400.0   1222.92  2065.08  735.72  25383.11   9489.87
# 2       700.0       400.0   1219.62  2087.19  743.58  25475.02   9552.05
# 3      3300.0      2700.0   1215.79  2147.00  737.66  25742.65   9608.38
# 4      2400.0     -1200.0   1216.39  2151.18  742.37  26269.89   9682.91
# ..        ...         ...       ...      ...     ...       ...       ...
# 422    1400.0      -700.0   1197.32  2704.48  852.79  34737.47  13791.15
# 423    1100.0      -400.0   1196.76  2676.54  839.92  34565.78  13790.92
# 424     700.0       200.0   1196.53  2729.68  878.15  34988.31  14139.76
# 425    1100.0         0.0   1198.63  2744.09  874.22  34935.59  14124.09
# 426    1100.0      -300.0   1195.59  2744.52  881.71  34311.18  13716.72
#
#        sp500
# 0    3029.73
# 1    3044.31
# 2    3055.73
# 3    3080.82
# 4    3122.87
# ..       ...
# 422  4418.64
# 423  4401.67
# 424  4471.07
# 425  4475.01
# 426  4380.26
#
# [427 rows x 15 columns]

# %%
# maN : N일전부터 현재까지의 종가 이동평균
newvariable_b=fdr.DataReader('005930', start = '20200518', end = end_date)[['Close']] #이동평균 만들고 na채워주려고 더 이전의 데이터 불러옴
ma10 = newvariable_b['Close'].rolling(window=10).mean()
ma10=pd.DataFrame(ma10.dropna()).reset_index()
ma10.columns=['Date','ma10']
df=pd.merge(newvariable_a,ma10, on="Date") #데이터에 이동평균 추가해주기
df=df.set_index('Date')

# %%
#볼린저밴드
k=2
#중심선 (MBB) : n일 이동평균선
mbb = newvariable_b.rolling(10).mean()
MA10_std = newvariable_b.rolling(10).std()
#상한선 (UBB) : 중심선 + (표준편차 × K)
#하한선 (LBB) : 중심선 - (표준편차 × K)
ubb=mbb+k*MA10_std
lbb=mbb-k*MA10_std
bb = ubb - lbb
bb.columns=['bb']
df=pd.merge(df,bb,on="Date")#볼린저밴드 데이터에 추가

# %%
df
# Out:
#               Close     Open     High      Low      Volume    Change  \
# Date
# 2020-05-29  50700.0  50000.0  50700.0  49700.0  27596961.0  0.005952
# 2020-06-01  51200.0  50800.0  51200.0  50600.0  16949183.0  0.009862
# 2020-06-02  51400.0  51000.0  51500.0  50800.0  14247933.0  0.003906
# 2020-06-03  54500.0  51800.0  55000.0  51700.0  49257814.0  0.060311
# 2020-06-04  54600.0  55800.0  57000.0  54600.0  40220334.0  0.001835
# ...             ...      ...      ...      ...         ...       ...
# 2022-02-14  73700.0  74400.0  74500.0  73100.0  13993255.0 -0.016021
# 2022-02-15  73700.0  74100.0  74200.0  73100.0   9320365.0  0.000000
# 2022-02-16  74800.0  74600.0  74900.0  74200.0  10767386.0  0.014925
# 2022-02-17  75000.0  75000.0  75600.0  74500.0  13605382.0  0.002674
# 2022-02-18  74300.0  74600.0  74800.0  73700.0  10122226.0 -0.009333
#
#             High-Low  Close-Open  exchange    kospi  kosdaq       dow  \
# Date
# 2020-05-29    1000.0       700.0   1231.49  2029.60  713.68  25400.64
# 2020-06-01     600.0       400.0   1222.92  2065.08  735.72  25383.11
# 2020-06-02     700.0       400.0   1219.62  2087.19  743.58  25475.02
# 2020-06-03    3300.0      2700.0   1215.79  2147.00  737.66  25742.65
# 2020-06-04    2400.0     -1200.0   1216.39  2151.18  742.37  26269.89
# ...              ...         ...       ...      ...     ...       ...
# 2022-02-14    1400.0      -700.0   1197.32  2704.48  852.79  34737.47
# 2022-02-15    1100.0      -400.0   1196.76  2676.54  839.92  34565.78
# 2022-02-16     700.0       200.0   1196.53  2729.68  878.15  34988.31
# 2022-02-17    1100.0         0.0   1198.63  2744.09  874.22  34935.59
# 2022-02-18    1100.0      -300.0   1195.59  2744.52  881.71  34311.18
#
#               nasdaq    sp500     ma10           bb
# Date
# 2020-05-29   9368.99  3029.73  49690.0  2884.132837
# 2020-06-01   9489.87  3044.31  49930.0  3152.706069
# 2020-06-02   9552.05  3055.73  50040.0  3650.022831
# 2020-06-03   9608.38  3080.82  50490.0  6714.362715
# 2020-06-04   9682.91  3122.87  50955.0  8411.341550
# ...              ...      ...      ...          ...
# 2022-02-14  13791.15  4418.64  73710.0  4624.379838
# 2022-02-15  13790.92  4401.67  73950.0  3167.894499
# 2022-02-16  14139.76  4471.07  74100.0  3188.869531
# 2022-02-17  14124.09  4475.01  74270.0  3155.524256
# 2022-02-18  13716.72  4380.26  74300.0  3132.624033
#
# [427 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# Close         0
# Open          0
# High          0
# Low           0
# Volume        0
# Change        0
# High-Low      0
# Close-Open    0
# exchange      0
# kospi         0
# kosdaq        0
# dow           0
# nasdaq        0
# sp500         0
# ma10          0
# bb            0
# dtype: int64

# %% [markdown]
# ------------- 모든 변수 넣은 df 데이터셋 완성-----

# %%
def label(x):
  if x>=0:
    Close=1
  else:
    Close=0
  return Close

# %%
df['Close'] = (df.Close - df.Close.shift(1))/df.Close.shift(1)*100
df=df.dropna()
df["Close"] = df["Close"].apply(lambda x:label(x))
df["Close"] = df["Close"].astype('category')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## 변수 선택 및 전처리 위한 EDA

# %%
#다중공선성확인 =>데이터 셋에 null 값 없어야지만 돌아감
import statsmodels.api as sm;
from statsmodels.stats.outliers_influence import variance_inflation_factor
df_vif=df.drop(['Close'],axis=1)

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(df_vif.values, i) for i in range(df_vif.shape[1])]
vif["features"] = df_vif.columns 
vif
#다중공선성 확인 결과 Open High Low sp500 제거!
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#        VIF Factor    features
# 0    89470.239242        Open
# 1   142126.017582        High
# 2    81966.875236         Low
# 3       19.372171      Volume
# 4        3.298499      Change
# 5       46.911308    High-Low
# 6        7.489996  Close-Open
# 7      433.300846    exchange
# 8     2995.973345       kospi
# 9     2194.263231      kosdaq
# 10   11268.800221         dow
# 11    4123.106452      nasdaq
# 12   12116.374736       sp500
# 13    2894.722360        ma10
# 14       6.721387          bb

# %%
df.dtypes
# Out:
# Close         category
# Open           float64
# High           float64
# Low            float64
# Volume         float64
# Change         float64
# High-Low       float64
# Close-Open     float64
# exchange       float64
# kospi          float64
# kosdaq         float64
# dow            float64
# nasdaq         float64
# sp500          float64
# ma10           float64
# bb             float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change', 'High-Low',
#        'Close-Open', 'exchange', 'kospi', 'kosdaq', 'dow', 'nasdaq', 'sp500',
#        'ma10', 'bb'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Open          High           Low        Volume      Change  \
# count    426.000000    426.000000    426.000000  4.260000e+02  426.000000
# mean   72294.131455  72939.906103  71615.258216  1.928498e+07    0.000766
# std    10563.187501  10630.150416  10520.549172  8.729558e+06    0.015202
# min    50800.000000  51200.000000  49900.000000  8.395448e+06   -0.045889
# 25%    60700.000000  61025.000000  60175.000000  1.350923e+07   -0.008395
# 50%    75350.000000  75900.000000  74500.000000  1.705522e+07    0.000000
# 75%    81000.000000  81400.000000  80450.000000  2.224766e+07    0.008272
# max    90300.000000  96800.000000  89500.000000  9.030618e+07    0.071170
#
#           High-Low   Close-Open     exchange        kospi       kosdaq  \
# count   426.000000   426.000000   426.000000   426.000000   426.000000
# mean   1323.474178   -83.802817  1154.097300  2835.994836   934.520188
# std     784.654676   939.133818    36.367053   371.529070    89.693081
# min     400.000000 -2500.000000  1083.530000  2030.820000   693.150000
# 25%     800.000000  -600.000000  1120.070000  2433.242500   866.802500
# 50%    1100.000000  -100.000000  1156.295000  2986.215000   963.155000
# 75%    1600.000000   375.000000  1187.147500  3140.460000  1004.680000
# max    7300.000000  5500.000000  1222.920000  3305.210000  1060.000000
#
#                 dow        nasdaq        sp500          ma10            bb
# count    426.000000    426.000000   426.000000    426.000000    426.000000
# mean   32005.491854  13268.394085  3985.762887  71963.028169   5104.529851
# std     3413.682407   1756.234562   511.641878  10707.503399   3120.338902
# min    25015.550000   9489.870000  3002.100000  49930.000000    942.809042
# 25%    28647.712500  11770.412500  3510.820000  59945.000000   2728.362111
# 50%    33515.380000  13629.455000  4088.560000  75340.000000   4248.812346
# 75%    34898.035000  14683.717500  4436.692500  80730.000000   6573.297864
# max    36799.650000  16057.440000  4796.560000  88510.000000  18408.886743

# %%
#주가변동확인
samsungstock2 = fdr.DataReader('005930', start = '20190601', end = '20211105')[['Close']]
plt.figure(figsize=(32,8))
plt.plot(samsungstock2.Close)
plt.show()

# %%
#삼성전자 상관분석
plt.figure(figsize=(10,10))
sns.set(font_scale=2)
sns.heatmap(df.corr(),
               annot= True,
               annot_kws={"size": 10})
#open high low snp500 제거 해야할듯

# %%
#밀도만 확인
for col in df.columns:
    if col in ['Volume','Change','High-Low','Close-Open','exchange','kospi',
              'kosdaq','dow','nasdaq','ma10','bb']:
        sns.kdeplot(data=df, x=df[col], shade = True)
        plt.figure(figsize=(10,5))

# %%
#사분위수로 이상치 확인
for col in df.columns:
    if col in ['Volume','Change','High-Low','exchange','kospi',
              'kosdaq','dow','nasdaq','ma10','bb']:
        sns.boxplot(data=df, x=df[col])
        plt.figure(figsize=(10,5))

# %%
#분포도 확인(밀도 포함)
for col in df.columns:
    if col in ['Volume','Change','High-Low','exchange','kospi',
              'kosdaq','dow','nasdaq','ma10','bb']:
        sns.displot(data=df, x=df[col], kde=True, rug=True)
        plt.figure(figsize=(15,10))

# %%
#EDA로사용하지 않을 변수들 제거
df=df.drop(['Open','High','Low','sp500'],axis=1)

# %%
df
# Out:
#            Close      Volume    Change  High-Low  Close-Open  exchange  \
# Date
# 2020-06-01     1  16949183.0  0.009862     600.0       400.0   1222.92
# 2020-06-02     1  14247933.0  0.003906     700.0       400.0   1219.62
# 2020-06-03     1  49257814.0  0.060311    3300.0      2700.0   1215.79
# 2020-06-04     1  40220334.0  0.001835    2400.0     -1200.0   1216.39
# 2020-06-05     1  22743629.0  0.016484    1900.0      1100.0   1202.02
# ...          ...         ...       ...       ...         ...       ...
# 2022-02-14     0  13993255.0 -0.016021    1400.0      -700.0   1197.32
# 2022-02-15     1   9320365.0  0.000000    1100.0      -400.0   1196.76
# 2022-02-16     1  10767386.0  0.014925     700.0       200.0   1196.53
# 2022-02-17     1  13605382.0  0.002674    1100.0         0.0   1198.63
# 2022-02-18     0  10122226.0 -0.009333    1100.0      -300.0   1195.59
#
#               kospi  kosdaq       dow    nasdaq     ma10           bb
# Date
# 2020-06-01  2065.08  735.72  25383.11   9489.87  49930.0  3152.706069
# 2020-06-02  2087.19  743.58  25475.02   9552.05  50040.0  3650.022831
# 2020-06-03  2147.00  737.66  25742.65   9608.38  50490.0  6714.362715
# 2020-06-04  2151.18  742.37  26269.89   9682.91  50955.0  8411.341550
# 2020-06-05  2181.87  749.31  26281.82   9615.81  51630.0  9525.264651
# ...             ...     ...       ...       ...      ...          ...
# 2022-02-14  2704.48  852.79  34737.47  13791.15  73710.0  4624.379838
# 2022-02-15  2676.54  839.92  34565.78  13790.92  73950.0  3167.894499
# 2022-02-16  2729.68  878.15  34988.31  14139.76  74100.0  3188.869531
# 2022-02-17  2744.09  874.22  34935.59  14124.09  74270.0  3155.524256
# 2022-02-18  2744.52  881.71  34311.18  13716.72  74300.0  3132.624033
#
# [426 rows x 12 columns]

# %% [markdown]
# 최종 데이터셋 = df

# %% [markdown]
# # 로그변환

# %%
#로그변환 먼저해야한다고함 (왜도 심한 변수들 로그변환!)
df['Volume']=np.log(df['Volume'])
df['High-Low']=np.log(df['High-Low'])
df['bb']=np.log(df['bb'])

# %% [markdown]
# ## 변수 스케일링

# %% [markdown]
# minmax 정규화 함수를 정의합니다
# - 첫번째 범위 : 0 ~ 1 ->양수만 있는 경우
# - 두번째 범위 : -1 ~ 1 -> 음수도 있는 경우

# %%
def minmax_norm1(df_input):
    return (df_input - df_input.min()) / ( df_input.max() - df_input.min())

# %%
def minmax_norm2(df_input):
    return 2*(df_input - df_input.min()) / ( df_input.max() - df_input.min())-1

# %% [markdown]
# Change와 Close-Open의 경우만 음수가 존재하므로 해당 데이터를 제외한 df를 생성합니다

# %%
df_tempo = df.drop(['Close-Open', 'Close', 'Change'], axis=1) #change는 빼주기 >> 원래분포가 -1에서 1사이로 보임 굳이 변환할필요 없어보인다!
df_tempo
# Out:
#                Volume  High-Low  exchange    kospi  kosdaq       dow  \
# Date
# 2020-06-01  16.645730  6.396930   1222.92  2065.08  735.72  25383.11
# 2020-06-02  16.472122  6.551080   1219.62  2087.19  743.58  25475.02
# 2020-06-03  17.712579  8.101678   1215.79  2147.00  737.66  25742.65
# 2020-06-04  17.509883  7.783224   1216.39  2151.18  742.37  26269.89
# 2020-06-05  16.939796  7.549609   1202.02  2181.87  749.31  26281.82
# ...               ...       ...       ...      ...     ...       ...
# 2022-02-14  16.454086  7.244228   1197.32  2704.48  852.79  34737.47
# 2022-02-15  16.047712  7.003065   1196.76  2676.54  839.92  34565.78
# 2022-02-16  16.192032  6.551080   1196.53  2729.68  878.15  34988.31
# 2022-02-17  16.425976  7.003065   1198.63  2744.09  874.22  34935.59
# 2022-02-18  16.130244  7.003065   1195.59  2744.52  881.71  34311.18
#
#               nasdaq     ma10        bb
# Date
# 2020-06-01   9489.87  49930.0  8.056016
# 2020-06-02   9552.05  50040.0  8.202489
# 2020-06-03   9608.38  50490.0  8.812004
# 2020-06-04   9682.91  50955.0  9.037336
# 2020-06-05   9615.81  51630.0  9.161703
# ...              ...      ...       ...
# 2022-02-14  13791.15  73710.0  8.439098
# 2022-02-15  13790.92  73950.0  8.060822
# 2022-02-16  14139.76  74100.0  8.067422
# 2022-02-17  14124.09  74270.0  8.056910
# 2022-02-18  13716.72  74300.0  8.049626
#
# [426 rows x 9 columns]

# %% [markdown]
# 첫번재 함수로 정규화를 진행합니다

# %%
df_tempo=minmax_norm1(df_tempo)
df_tempo
# Out:
#               Volume  High-Low  exchange     kospi    kosdaq       dow  \
# Date
# 2020-06-01  0.295738  0.139615  1.000000  0.026883  0.116042  0.031191
# 2020-06-02  0.222656  0.192694  0.976325  0.044233  0.137468  0.038991
# 2020-06-03  0.744840  0.726616  0.948849  0.091165  0.121330  0.061702
# 2020-06-04  0.659513  0.616962  0.953153  0.094445  0.134169  0.106443
# 2020-06-05  0.419528  0.536521  0.850061  0.118527  0.153087  0.107456
# ...              ...       ...       ...       ...       ...       ...
# 2022-02-14  0.215063  0.431368  0.816343  0.528614  0.435164  0.825003
# 2022-02-15  0.043996  0.348328  0.812325  0.506689  0.400082  0.810434
# 2022-02-16  0.104749  0.192694  0.810675  0.548388  0.504293  0.846289
# 2022-02-17  0.203230  0.348328  0.825741  0.559695  0.493580  0.841816
# 2022-02-18  0.078738  0.348328  0.803931  0.560033  0.513998  0.788828
#
#               nasdaq      ma10        bb
# Date
# 2020-06-01  0.000000  0.000000  0.406213
# 2020-06-02  0.009468  0.002851  0.455501
# 2020-06-03  0.018045  0.014515  0.660606
# 2020-06-04  0.029393  0.026568  0.736432
# 2020-06-05  0.019176  0.044064  0.778282
# ...              ...       ...       ...
# 2022-02-14  0.654927  0.616382  0.535121
# 2022-02-15  0.654892  0.622602  0.407830
# 2022-02-16  0.708008  0.626490  0.410051
# 2022-02-17  0.705622  0.630897  0.406513
# 2022-02-18  0.643594  0.631674  0.404062
#
# [426 rows x 9 columns]

# %% [markdown]
# 음수가 포함된 변수들만으로 이루어진 데이터셋을 만듭니다

# %%
df_tempo2=df[['Change','Close-Open']]
df_tempo2
# Out:
#               Change  Close-Open
# Date
# 2020-06-01  0.009862       400.0
# 2020-06-02  0.003906       400.0
# 2020-06-03  0.060311      2700.0
# 2020-06-04  0.001835     -1200.0
# 2020-06-05  0.016484      1100.0
# ...              ...         ...
# 2022-02-14 -0.016021      -700.0
# 2022-02-15  0.000000      -400.0
# 2022-02-16  0.014925       200.0
# 2022-02-17  0.002674         0.0
# 2022-02-18 -0.009333      -300.0
#
# [426 rows x 2 columns]

# %% [markdown]
# 정규화를 진행합니다

# %%
df_tempo2=minmax_norm2(df_tempo2)
df_tempo2
# Out:
#               Change  Close-Open
# Date
# 2020-06-01 -0.047473      -0.275
# 2020-06-02 -0.149228      -0.275
# 2020-06-03  0.814473       0.300
# 2020-06-04 -0.184618      -0.675
# 2020-06-05  0.065660      -0.100
# ...              ...         ...
# 2022-02-14 -0.489698      -0.550
# 2022-02-15 -0.215968      -0.475
# 2022-02-16  0.039038      -0.325
# 2022-02-17 -0.170285      -0.375
# 2022-02-18 -0.375431      -0.450
#
# [426 rows x 2 columns]

# %% [markdown]
# 둘을 합치면 정규화가 완료된 데이터셋이 완성됩니다.(혹시 모를 상황으로 지워질지 몰라서 원본 유지를 위해 다른 데이터 셋을 형성했습니다.)

# %%
df2 = pd.concat([df['Close'], df_tempo, df_tempo2],axis=1)
df2
# Out:
#            Close    Volume  High-Low  exchange     kospi    kosdaq       dow  \
# Date
# 2020-06-01     1  0.295738  0.139615  1.000000  0.026883  0.116042  0.031191
# 2020-06-02     1  0.222656  0.192694  0.976325  0.044233  0.137468  0.038991
# 2020-06-03     1  0.744840  0.726616  0.948849  0.091165  0.121330  0.061702
# 2020-06-04     1  0.659513  0.616962  0.953153  0.094445  0.134169  0.106443
# 2020-06-05     1  0.419528  0.536521  0.850061  0.118527  0.153087  0.107456
# ...          ...       ...       ...       ...       ...       ...       ...
# 2022-02-14     0  0.215063  0.431368  0.816343  0.528614  0.435164  0.825003
# 2022-02-15     1  0.043996  0.348328  0.812325  0.506689  0.400082  0.810434
# 2022-02-16     1  0.104749  0.192694  0.810675  0.548388  0.504293  0.846289
# 2022-02-17     1  0.203230  0.348328  0.825741  0.559695  0.493580  0.841816
# 2022-02-18     0  0.078738  0.348328  0.803931  0.560033  0.513998  0.788828
#
#               nasdaq      ma10        bb    Change  Close-Open
# Date
# 2020-06-01  0.000000  0.000000  0.406213 -0.047473      -0.275
# 2020-06-02  0.009468  0.002851  0.455501 -0.149228      -0.275
# 2020-06-03  0.018045  0.014515  0.660606  0.814473       0.300
# 2020-06-04  0.029393  0.026568  0.736432 -0.184618      -0.675
# 2020-06-05  0.019176  0.044064  0.778282  0.065660      -0.100
# ...              ...       ...       ...       ...         ...
# 2022-02-14  0.654927  0.616382  0.535121 -0.489698      -0.550
# 2022-02-15  0.654892  0.622602  0.407830 -0.215968      -0.475
# 2022-02-16  0.708008  0.626490  0.410051  0.039038      -0.325
# 2022-02-17  0.705622  0.630897  0.406513 -0.170285      -0.375
# 2022-02-18  0.643594  0.631674  0.404062 -0.375431      -0.450
#
# [426 rows x 12 columns]

# %% [markdown]
# ***

# %% [markdown]
# # 모델링

# %%
# 최종 예측할 5일의 데이터 셋 형성
day_list = ['2022-02-14', '2022-02-15', '2022-02-16', '2022-02-17', '2022-02-18']

df_recent = df2.loc[day_list]
df_recent
# Out:
#            Close    Volume  High-Low  exchange     kospi    kosdaq       dow  \
# Date
# 2022-02-14     0  0.215063  0.431368  0.816343  0.528614  0.435164  0.825003
# 2022-02-15     1  0.043996  0.348328  0.812325  0.506689  0.400082  0.810434
# 2022-02-16     1  0.104749  0.192694  0.810675  0.548388  0.504293  0.846289
# 2022-02-17     1  0.203230  0.348328  0.825741  0.559695  0.493580  0.841816
# 2022-02-18     0  0.078738  0.348328  0.803931  0.560033  0.513998  0.788828
#
#               nasdaq      ma10        bb    Change  Close-Open
# Date
# 2022-02-14  0.654927  0.616382  0.535121 -0.489698      -0.550
# 2022-02-15  0.654892  0.622602  0.407830 -0.215968      -0.475
# 2022-02-16  0.708008  0.626490  0.410051  0.039038      -0.325
# 2022-02-17  0.705622  0.630897  0.406513 -0.170285      -0.375
# 2022-02-18  0.643594  0.631674  0.404062 -0.375431      -0.450

# %%
# 학습, 테스트, 검증할 데이터셋 형성
df_fellow = df2.drop([df2.index[-10],df2.index[-9],df2.index[-8],df2.index[-7],df2.index[-6],df2.index[-5],df2.index[-4],df2.index[-3],df2.index[-2],df2.index[-1]])
df_fellow
# Out:
#            Close    Volume  High-Low  exchange     kospi    kosdaq       dow  \
# Date
# 2020-06-01     1  0.295738  0.139615  1.000000  0.026883  0.116042  0.031191
# 2020-06-02     1  0.222656  0.192694  0.976325  0.044233  0.137468  0.038991
# 2020-06-03     1  0.744840  0.726616  0.948849  0.091165  0.121330  0.061702
# 2020-06-04     1  0.659513  0.616962  0.953153  0.094445  0.134169  0.106443
# 2020-06-05     1  0.419528  0.536521  0.850061  0.118527  0.153087  0.107456
# ...          ...       ...       ...       ...       ...       ...       ...
# 2022-01-26     0  0.183315  0.405850  0.814262  0.532349  0.515033  0.787687
# 2022-01-27     0  0.410759  0.657519  0.862616  0.458000  0.425460  0.776686
# 2022-01-28     1  0.393253  0.631018  0.904154  0.496332  0.489901  0.776065
# 2022-02-03     1  0.315047  0.477347  0.831767  0.531235  0.540957  0.900687
# 2022-02-04     1  0.175235  0.378289  0.823015  0.564537  0.571678  0.856715
#
#               nasdaq      ma10        bb    Change  Close-Open
# Date
# 2020-06-01  0.000000  0.000000  0.406213 -0.047473      -0.275
# 2020-06-02  0.009468  0.002851  0.455501 -0.149228      -0.275
# 2020-06-03  0.018045  0.014515  0.660606  0.814473       0.300
# 2020-06-04  0.029393  0.026568  0.736432 -0.184618      -0.675
# 2020-06-05  0.019176  0.044064  0.778282  0.065660      -0.100
# ...              ...       ...       ...       ...         ...
# 2022-01-26  0.616578  0.677035  0.629871 -0.377586      -0.525
# 2022-01-27  0.617009  0.659927  0.719134 -0.682144      -1.000
# 2022-01-28  0.588179  0.649559  0.714959  0.263286       0.125
# 2022-02-03  0.750305  0.638673  0.687877 -0.215968      -0.775
# 2022-02-04  0.668276  0.630897  0.646654 -0.052806      -0.450
#
# [416 rows x 12 columns]

# %%
X = df_fellow[["Volume","Change","High-Low","exchange","kospi","kosdaq","dow","nasdaq","ma10","bb","Close-Open"]]
X
y=df_fellow[["Close"]]

# %%
y
# Out:
#            Close
# Date
# 2020-06-01     1
# 2020-06-02     1
# 2020-06-03     1
# 2020-06-04     1
# 2020-06-05     1
# ...          ...
# 2022-01-26     0
# 2022-01-27     0
# 2022-01-28     1
# 2022-02-03     1
# 2022-02-04     1
#
# [416 rows x 1 columns]

# %%
# 훈련, 테스트 셋 분리
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=False)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (332, 11)
# (84, 11)
# (332, 1)
# (84, 1)

# %%
# 데이터프레임 -> 넘파이 변환
# X: 2차원 -> 3차원 변환
X_train = X_train.to_numpy().reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.to_numpy().reshape(X_test.shape[0], X_test.shape[1], 1)
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, BatchNormalization, Activation

# %%
model = Sequential()  # 시퀀셜 모델 생성
model.add(GRU(128, activation='tanh', input_shape=X_train[0].shape))   # GRU 레이어
#model.add(Dense(128, activation='tanh', input_shape=X_train[0].shape))   # FC 레이어
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))   # FC 레이어
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))   # FC 레이어
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))   # FC 레이어

# %%
# 컴파일
model.compile(loss='binary_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_7 (GRU)                 (None, 128)               50304
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 64)                8256
#
#  dropout_22 (Dropout)        (None, 64)                0
#
#  dense_22 (Dense)            (None, 32)                2080
#
#  dropout_23 (Dropout)        (None, 32)                0
#
#  dense_23 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 60,673
# Trainable params: 60,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
# n번(patience)의 에포크 이상 검증 세트에서의 손실이 감소하지 않으면 학습 자동 중단
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5)

# %%
# 학습
hist = model.fit(X_train, y_train,
                 epochs=105,
                 batch_size=32,
                 validation_split=0.2,
                 shuffle=False)
# Out:
# Epoch 1/105
# 9/9 [==============================] - 4s 156ms/step - loss: 0.6912 - accuracy: 0.5585 - precision_7: 0.5582 - recall_7: 0.9521 - val_loss: 0.6930 - val_accuracy: 0.4627 - val_precision_7: 0.4627 - val_recall_7: 1.0000
# Epoch 2/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6741 - accuracy: 0.5774 - precision_7: 0.5659 - recall_7: 1.0000 - val_loss: 0.6900 - val_accuracy: 0.4627 - val_precision_7: 0.4627 - val_recall_7: 1.0000
# Epoch 3/105
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6620 - accuracy: 0.6038 - precision_7: 0.5823 - recall_7: 0.9932 - val_loss: 0.6793 - val_accuracy: 0.4627 - val_precision_7: 0.4627 - val_recall_7: 1.0000
# Epoch 4/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6530 - accuracy: 0.6264 - precision_7: 0.5983 - recall_7: 0.9795 - val_loss: 0.6581 - val_accuracy: 0.5373 - val_precision_7: 0.5000 - val_recall_7: 1.0000
# Epoch 5/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6333 - accuracy: 0.6566 - precision_7: 0.6329 - recall_7: 0.8973 - val_loss: 0.6291 - val_accuracy: 0.7015 - val_precision_7: 0.6170 - val_recall_7: 0.9355
# Epoch 6/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6133 - accuracy: 0.7170 - precision_7: 0.7076 - recall_7: 0.8288 - val_loss: 0.6118 - val_accuracy: 0.6866 - val_precision_7: 0.6042 - val_recall_7: 0.9355
# Epoch 7/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6061 - accuracy: 0.6717 - precision_7: 0.6545 - recall_7: 0.8562 - val_loss: 0.5770 - val_accuracy: 0.7761 - val_precision_7: 0.7000 - val_recall_7: 0.9032
# Epoch 8/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5836 - accuracy: 0.7283 - precision_7: 0.7534 - recall_7: 0.7534 - val_loss: 0.5572 - val_accuracy: 0.7612 - val_precision_7: 0.7027 - val_recall_7: 0.8387
# Epoch 9/105
# 9/9 [==============================] - 0s 14ms/step - loss: 0.5570 - accuracy: 0.7208 - precision_7: 0.7045 - recall_7: 0.8493 - val_loss: 0.5314 - val_accuracy: 0.7761 - val_precision_7: 0.7353 - val_recall_7: 0.8065
# Epoch 10/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5316 - accuracy: 0.7585 - precision_7: 0.7697 - recall_7: 0.8014 - val_loss: 0.5003 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 11/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5068 - accuracy: 0.7623 - precision_7: 0.7785 - recall_7: 0.7945 - val_loss: 0.4754 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 12/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5093 - accuracy: 0.7774 - precision_7: 0.7959 - recall_7: 0.8014 - val_loss: 0.4590 - val_accuracy: 0.7910 - val_precision_7: 0.7931 - val_recall_7: 0.7419
# Epoch 13/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5112 - accuracy: 0.7660 - precision_7: 0.8134 - recall_7: 0.7466 - val_loss: 0.4503 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 14/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5038 - accuracy: 0.7660 - precision_7: 0.7763 - recall_7: 0.8082 - val_loss: 0.4556 - val_accuracy: 0.7761 - val_precision_7: 0.7667 - val_recall_7: 0.7419
# Epoch 15/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4879 - accuracy: 0.7849 - precision_7: 0.8248 - recall_7: 0.7740 - val_loss: 0.4707 - val_accuracy: 0.7910 - val_precision_7: 0.7297 - val_recall_7: 0.8710
# Epoch 16/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5033 - accuracy: 0.7736 - precision_7: 0.7654 - recall_7: 0.8493 - val_loss: 0.4699 - val_accuracy: 0.7612 - val_precision_7: 0.8947 - val_recall_7: 0.5484
# Epoch 17/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5203 - accuracy: 0.7321 - precision_7: 0.7698 - recall_7: 0.7329 - val_loss: 0.4420 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 18/105
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4893 - accuracy: 0.7660 - precision_7: 0.8134 - recall_7: 0.7466 - val_loss: 0.4500 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 19/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4924 - accuracy: 0.7849 - precision_7: 0.7871 - recall_7: 0.8356 - val_loss: 0.4502 - val_accuracy: 0.7910 - val_precision_7: 0.7742 - val_recall_7: 0.7742
# Epoch 20/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4877 - accuracy: 0.7774 - precision_7: 0.8222 - recall_7: 0.7603 - val_loss: 0.4477 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 21/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4781 - accuracy: 0.7887 - precision_7: 0.7961 - recall_7: 0.8288 - val_loss: 0.4375 - val_accuracy: 0.7761 - val_precision_7: 0.7500 - val_recall_7: 0.7742
# Epoch 22/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4879 - accuracy: 0.7736 - precision_7: 0.8162 - recall_7: 0.7603 - val_loss: 0.4383 - val_accuracy: 0.7761 - val_precision_7: 0.7353 - val_recall_7: 0.8065
# Epoch 23/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4968 - accuracy: 0.7660 - precision_7: 0.7958 - recall_7: 0.7740 - val_loss: 0.4374 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 24/105
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4924 - accuracy: 0.7811 - precision_7: 0.7857 - recall_7: 0.8288 - val_loss: 0.4344 - val_accuracy: 0.7910 - val_precision_7: 0.7931 - val_recall_7: 0.7419
# Epoch 25/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5153 - accuracy: 0.7321 - precision_7: 0.8261 - recall_7: 0.6507 - val_loss: 0.4384 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 26/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4915 - accuracy: 0.7887 - precision_7: 0.7647 - recall_7: 0.8904 - val_loss: 0.4483 - val_accuracy: 0.7612 - val_precision_7: 0.8261 - val_recall_7: 0.6129
# Epoch 27/105
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5225 - accuracy: 0.7358 - precision_7: 0.8800 - recall_7: 0.6027 - val_loss: 0.4463 - val_accuracy: 0.7910 - val_precision_7: 0.7931 - val_recall_7: 0.7419
# Epoch 28/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5008 - accuracy: 0.7736 - precision_7: 0.7471 - recall_7: 0.8904 - val_loss: 0.4561 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 29/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4708 - accuracy: 0.7962 - precision_7: 0.8433 - recall_7: 0.7740 - val_loss: 0.4499 - val_accuracy: 0.7910 - val_precision_7: 0.7931 - val_recall_7: 0.7419
# Epoch 30/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4738 - accuracy: 0.7887 - precision_7: 0.8000 - recall_7: 0.8219 - val_loss: 0.4451 - val_accuracy: 0.7761 - val_precision_7: 0.7353 - val_recall_7: 0.8065
# Epoch 31/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4709 - accuracy: 0.8113 - precision_7: 0.8200 - recall_7: 0.8425 - val_loss: 0.4324 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 32/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4547 - accuracy: 0.7849 - precision_7: 0.7908 - recall_7: 0.8288 - val_loss: 0.4225 - val_accuracy: 0.7761 - val_precision_7: 0.7500 - val_recall_7: 0.7742
# Epoch 33/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4579 - accuracy: 0.7962 - precision_7: 0.8239 - recall_7: 0.8014 - val_loss: 0.4167 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 34/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4785 - accuracy: 0.7887 - precision_7: 0.8125 - recall_7: 0.8014 - val_loss: 0.4238 - val_accuracy: 0.8060 - val_precision_7: 0.7500 - val_recall_7: 0.8710
# Epoch 35/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4726 - accuracy: 0.8151 - precision_7: 0.8170 - recall_7: 0.8562 - val_loss: 0.4139 - val_accuracy: 0.8060 - val_precision_7: 0.8000 - val_recall_7: 0.7742
# Epoch 36/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4750 - accuracy: 0.7698 - precision_7: 0.8195 - recall_7: 0.7466 - val_loss: 0.4322 - val_accuracy: 0.7910 - val_precision_7: 0.7297 - val_recall_7: 0.8710
# Epoch 37/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4707 - accuracy: 0.7962 - precision_7: 0.7805 - recall_7: 0.8767 - val_loss: 0.4182 - val_accuracy: 0.8060 - val_precision_7: 0.8000 - val_recall_7: 0.7742
# Epoch 38/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4609 - accuracy: 0.8000 - precision_7: 0.8496 - recall_7: 0.7740 - val_loss: 0.4212 - val_accuracy: 0.7910 - val_precision_7: 0.7297 - val_recall_7: 0.8710
# Epoch 39/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4410 - accuracy: 0.7849 - precision_7: 0.7987 - recall_7: 0.8151 - val_loss: 0.3912 - val_accuracy: 0.7910 - val_precision_7: 0.7576 - val_recall_7: 0.8065
# Epoch 40/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4267 - accuracy: 0.8000 - precision_7: 0.8345 - recall_7: 0.7945 - val_loss: 0.3989 - val_accuracy: 0.8209 - val_precision_7: 0.7436 - val_recall_7: 0.9355
# Epoch 41/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4150 - accuracy: 0.8151 - precision_7: 0.8345 - recall_7: 0.8288 - val_loss: 0.4472 - val_accuracy: 0.8060 - val_precision_7: 0.7045 - val_recall_7: 1.0000
# Epoch 42/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4035 - accuracy: 0.8302 - precision_7: 0.8389 - recall_7: 0.8562 - val_loss: 0.6326 - val_accuracy: 0.7015 - val_precision_7: 0.6078 - val_recall_7: 1.0000
# Epoch 43/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4936 - accuracy: 0.8113 - precision_7: 0.8117 - recall_7: 0.8562 - val_loss: 0.5090 - val_accuracy: 0.7015 - val_precision_7: 1.0000 - val_recall_7: 0.3548
# Epoch 44/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5620 - accuracy: 0.7057 - precision_7: 0.9146 - recall_7: 0.5137 - val_loss: 0.5575 - val_accuracy: 0.6866 - val_precision_7: 0.5962 - val_recall_7: 1.0000
# Epoch 45/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5078 - accuracy: 0.7585 - precision_7: 0.7412 - recall_7: 0.8630 - val_loss: 0.3999 - val_accuracy: 0.8209 - val_precision_7: 0.8519 - val_recall_7: 0.7419
# Epoch 46/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5499 - accuracy: 0.6755 - precision_7: 0.9286 - recall_7: 0.4452 - val_loss: 0.5492 - val_accuracy: 0.6716 - val_precision_7: 1.0000 - val_recall_7: 0.2903
# Epoch 47/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5102 - accuracy: 0.7509 - precision_7: 0.8030 - recall_7: 0.7260 - val_loss: 0.4924 - val_accuracy: 0.8060 - val_precision_7: 0.7500 - val_recall_7: 0.8710
# Epoch 48/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4922 - accuracy: 0.7585 - precision_7: 0.7228 - recall_7: 0.9110 - val_loss: 0.4472 - val_accuracy: 0.8060 - val_precision_7: 0.8000 - val_recall_7: 0.7742
# Epoch 49/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4479 - accuracy: 0.8075 - precision_7: 0.8467 - recall_7: 0.7945 - val_loss: 0.4107 - val_accuracy: 0.8209 - val_precision_7: 0.8065 - val_recall_7: 0.8065
# Epoch 50/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4212 - accuracy: 0.8415 - precision_7: 0.8421 - recall_7: 0.8767 - val_loss: 0.3893 - val_accuracy: 0.8358 - val_precision_7: 0.7941 - val_recall_7: 0.8710
# Epoch 51/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4120 - accuracy: 0.8340 - precision_7: 0.8923 - recall_7: 0.7945 - val_loss: 0.3559 - val_accuracy: 0.8507 - val_precision_7: 0.8182 - val_recall_7: 0.8710
# Epoch 52/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3836 - accuracy: 0.8642 - precision_7: 0.8571 - recall_7: 0.9041 - val_loss: 0.3208 - val_accuracy: 0.8806 - val_precision_7: 0.8710 - val_recall_7: 0.8710
# Epoch 53/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3311 - accuracy: 0.8868 - precision_7: 0.9028 - recall_7: 0.8904 - val_loss: 0.3048 - val_accuracy: 0.8507 - val_precision_7: 0.8621 - val_recall_7: 0.8065
# Epoch 54/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3138 - accuracy: 0.8792 - precision_7: 0.9071 - recall_7: 0.8699 - val_loss: 0.2918 - val_accuracy: 0.8806 - val_precision_7: 0.8710 - val_recall_7: 0.8710
# Epoch 55/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2801 - accuracy: 0.8830 - precision_7: 0.9078 - recall_7: 0.8767 - val_loss: 0.3530 - val_accuracy: 0.8507 - val_precision_7: 0.7838 - val_recall_7: 0.9355
# Epoch 56/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2992 - accuracy: 0.8604 - precision_7: 0.8759 - recall_7: 0.8699 - val_loss: 0.3525 - val_accuracy: 0.8657 - val_precision_7: 0.7895 - val_recall_7: 0.9677
# Epoch 57/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2905 - accuracy: 0.8830 - precision_7: 0.8710 - recall_7: 0.9247 - val_loss: 0.2453 - val_accuracy: 0.9254 - val_precision_7: 1.0000 - val_recall_7: 0.8387
# Epoch 58/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6164 - accuracy: 0.7283 - precision_7: 0.7434 - recall_7: 0.7740 - val_loss: 0.2844 - val_accuracy: 0.9254 - val_precision_7: 0.9062 - val_recall_7: 0.9355
# Epoch 59/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5213 - accuracy: 0.7321 - precision_7: 1.0000 - recall_7: 0.5137 - val_loss: 0.4773 - val_accuracy: 0.6866 - val_precision_7: 1.0000 - val_recall_7: 0.3226
# Epoch 60/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4217 - accuracy: 0.8528 - precision_7: 0.9280 - recall_7: 0.7945 - val_loss: 0.4469 - val_accuracy: 0.8507 - val_precision_7: 0.7561 - val_recall_7: 1.0000
# Epoch 61/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3720 - accuracy: 0.8226 - precision_7: 0.7619 - recall_7: 0.9863 - val_loss: 0.3686 - val_accuracy: 0.8657 - val_precision_7: 0.7895 - val_recall_7: 0.9677
# Epoch 62/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2886 - accuracy: 0.9057 - precision_7: 0.9291 - recall_7: 0.8973 - val_loss: 0.2692 - val_accuracy: 0.8806 - val_precision_7: 0.8710 - val_recall_7: 0.8710
# Epoch 63/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2540 - accuracy: 0.9170 - precision_7: 0.9133 - recall_7: 0.9384 - val_loss: 0.2295 - val_accuracy: 0.9104 - val_precision_7: 0.8788 - val_recall_7: 0.9355
# Epoch 64/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2123 - accuracy: 0.9283 - precision_7: 0.9320 - recall_7: 0.9384 - val_loss: 0.2112 - val_accuracy: 0.9104 - val_precision_7: 0.8788 - val_recall_7: 0.9355
# Epoch 65/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1892 - accuracy: 0.9358 - precision_7: 0.9388 - recall_7: 0.9452 - val_loss: 0.1802 - val_accuracy: 0.9104 - val_precision_7: 0.8788 - val_recall_7: 0.9355
# Epoch 66/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1732 - accuracy: 0.9358 - precision_7: 0.9388 - recall_7: 0.9452 - val_loss: 0.1264 - val_accuracy: 0.9552 - val_precision_7: 0.9667 - val_recall_7: 0.9355
# Epoch 67/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2147 - accuracy: 0.9283 - precision_7: 0.9150 - recall_7: 0.9589 - val_loss: 0.1322 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 68/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2861 - accuracy: 0.8755 - precision_7: 0.9065 - recall_7: 0.8630 - val_loss: 0.1516 - val_accuracy: 0.9254 - val_precision_7: 0.9062 - val_recall_7: 0.9355
# Epoch 69/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1956 - accuracy: 0.9358 - precision_7: 0.9708 - recall_7: 0.9110 - val_loss: 0.1422 - val_accuracy: 0.9552 - val_precision_7: 0.9667 - val_recall_7: 0.9355
# Epoch 70/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1710 - accuracy: 0.9396 - precision_7: 0.9333 - recall_7: 0.9589 - val_loss: 0.1246 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 71/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1542 - accuracy: 0.9472 - precision_7: 0.9583 - recall_7: 0.9452 - val_loss: 0.1064 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 72/105
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1360 - accuracy: 0.9547 - precision_7: 0.9589 - recall_7: 0.9589 - val_loss: 0.0924 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 73/105
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1450 - accuracy: 0.9509 - precision_7: 0.9586 - recall_7: 0.9521 - val_loss: 0.0884 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 74/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1421 - accuracy: 0.9472 - precision_7: 0.9521 - recall_7: 0.9521 - val_loss: 0.1716 - val_accuracy: 0.9104 - val_precision_7: 1.0000 - val_recall_7: 0.8065
# Epoch 75/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2305 - accuracy: 0.9019 - precision_7: 0.9615 - recall_7: 0.8562 - val_loss: 0.0923 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 76/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1254 - accuracy: 0.9585 - precision_7: 0.9787 - recall_7: 0.9452 - val_loss: 0.1108 - val_accuracy: 0.9552 - val_precision_7: 0.9375 - val_recall_7: 0.9677
# Epoch 77/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2154 - accuracy: 0.9208 - precision_7: 0.9562 - recall_7: 0.8973 - val_loss: 0.1161 - val_accuracy: 0.9552 - val_precision_7: 1.0000 - val_recall_7: 0.9032
# Epoch 78/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1526 - accuracy: 0.9434 - precision_7: 0.9226 - recall_7: 0.9795 - val_loss: 0.0844 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 79/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1619 - accuracy: 0.9434 - precision_7: 1.0000 - recall_7: 0.8973 - val_loss: 0.1075 - val_accuracy: 0.9552 - val_precision_7: 0.9375 - val_recall_7: 0.9677
# Epoch 80/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1185 - accuracy: 0.9509 - precision_7: 0.9463 - recall_7: 0.9658 - val_loss: 0.0926 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 81/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1114 - accuracy: 0.9547 - precision_7: 0.9653 - recall_7: 0.9521 - val_loss: 0.0797 - val_accuracy: 0.9701 - val_precision_7: 0.9677 - val_recall_7: 0.9677
# Epoch 82/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1019 - accuracy: 0.9736 - precision_7: 0.9860 - recall_7: 0.9658 - val_loss: 0.0762 - val_accuracy: 0.9701 - val_precision_7: 0.9677 - val_recall_7: 0.9677
# Epoch 83/105
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1306 - accuracy: 0.9698 - precision_7: 0.9726 - recall_7: 0.9726 - val_loss: 0.0977 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 84/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1658 - accuracy: 0.9358 - precision_7: 0.9574 - recall_7: 0.9247 - val_loss: 0.0711 - val_accuracy: 0.9701 - val_precision_7: 0.9677 - val_recall_7: 0.9677
# Epoch 85/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1218 - accuracy: 0.9585 - precision_7: 0.9787 - recall_7: 0.9452 - val_loss: 0.0744 - val_accuracy: 0.9701 - val_precision_7: 0.9677 - val_recall_7: 0.9677
# Epoch 86/105
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0926 - accuracy: 0.9736 - precision_7: 0.9728 - recall_7: 0.9795 - val_loss: 0.1004 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 87/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1022 - accuracy: 0.9774 - precision_7: 0.9861 - recall_7: 0.9726 - val_loss: 0.0756 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 88/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0798 - accuracy: 0.9811 - precision_7: 0.9796 - recall_7: 0.9863 - val_loss: 0.0799 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 89/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0845 - accuracy: 0.9811 - precision_7: 0.9796 - recall_7: 0.9863 - val_loss: 0.0846 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 90/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1130 - accuracy: 0.9698 - precision_7: 0.9726 - recall_7: 0.9726 - val_loss: 0.0776 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 91/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1082 - accuracy: 0.9660 - precision_7: 0.9724 - recall_7: 0.9658 - val_loss: 0.0939 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 92/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0828 - accuracy: 0.9736 - precision_7: 0.9929 - recall_7: 0.9589 - val_loss: 0.0907 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 93/105
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1020 - accuracy: 0.9698 - precision_7: 0.9726 - recall_7: 0.9726 - val_loss: 0.1491 - val_accuracy: 0.9552 - val_precision_7: 1.0000 - val_recall_7: 0.9032
# Epoch 94/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0755 - accuracy: 0.9774 - precision_7: 0.9730 - recall_7: 0.9863 - val_loss: 0.0880 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 95/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0784 - accuracy: 0.9774 - precision_7: 0.9730 - recall_7: 0.9863 - val_loss: 0.0822 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 96/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0494 - accuracy: 0.9925 - precision_7: 1.0000 - recall_7: 0.9863 - val_loss: 0.0777 - val_accuracy: 0.9851 - val_precision_7: 1.0000 - val_recall_7: 0.9677
# Epoch 97/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0836 - accuracy: 0.9774 - precision_7: 0.9795 - recall_7: 0.9795 - val_loss: 0.1132 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 98/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0861 - accuracy: 0.9774 - precision_7: 0.9795 - recall_7: 0.9795 - val_loss: 0.0952 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 99/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1526 - accuracy: 0.9547 - precision_7: 0.9718 - recall_7: 0.9452 - val_loss: 0.1583 - val_accuracy: 0.9552 - val_precision_7: 1.0000 - val_recall_7: 0.9032
# Epoch 100/105
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1797 - accuracy: 0.9208 - precision_7: 1.0000 - recall_7: 0.8562 - val_loss: 0.0962 - val_accuracy: 0.9552 - val_precision_7: 0.9667 - val_recall_7: 0.9355
# Epoch 101/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1891 - accuracy: 0.9283 - precision_7: 0.8994 - recall_7: 0.9795 - val_loss: 0.1105 - val_accuracy: 0.9552 - val_precision_7: 1.0000 - val_recall_7: 0.9032
# Epoch 102/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1142 - accuracy: 0.9585 - precision_7: 0.9927 - recall_7: 0.9315 - val_loss: 0.0908 - val_accuracy: 0.9701 - val_precision_7: 1.0000 - val_recall_7: 0.9355
# Epoch 103/105
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1041 - accuracy: 0.9585 - precision_7: 0.9412 - recall_7: 0.9863 - val_loss: 0.0662 - val_accuracy: 0.9701 - val_precision_7: 0.9677 - val_recall_7: 0.9677
# Epoch 104/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0790 - accuracy: 0.9774 - precision_7: 0.9795 - recall_7: 0.9795 - val_loss: 0.0743 - val_accuracy: 0.9851 - val_precision_7: 1.0000 - val_recall_7: 0.9677
# Epoch 105/105
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1061 - accuracy: 0.9774 - precision_7: 0.9795 - recall_7: 0.9795 - val_loss: 0.0626 - val_accuracy: 0.9701 - val_precision_7: 0.9677 - val_recall_7: 0.9677

# %% [markdown]
# https://snowdeer.github.io/machine-learning/2018/01/11/keras-use-history-function/
# Keras - history 기능 사용하기

# %%
# 학습곡선 시각화
fig, loss_plot = plt.subplots(figsize=(8,10))
loss_plot.plot(hist.history['loss'], 'y', label='train loss')
loss_plot.plot(hist.history['val_loss'], 'r', label='val loss')
plt.yticks(np.arange(0, 0.8, 0.05), fontsize=10)
plt.xticks(np.arange(0, 160, 10), fontsize=10)
loss_plot.legend(fontsize=14)
plt.show()

# %%
# 최종 성능 측정
eval = model.evaluate(X_test, y_test)
print(f'F1 Score: {2 * eval[2] * eval[3] / (eval[2] + eval[3])}')
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1293 - accuracy: 0.9405 - precision_7: 0.9130 - recall_7: 0.9767
# F1 Score: 0.9438202306186138

# %%
# 최근 종가로 예측해보기
eval_recent = model.evaluate(df_recent[["Volume","Change","High-Low","exchange","kospi","kosdaq","dow","nasdaq","ma10","bb","Close-Open"]], df_recent[['Close']])
print(f'F1 Score: {2 * eval_recent[2] * eval_recent[3] / (eval_recent[2] + eval_recent[3])}')
# Out:
# 1/1 [==============================] - 1s 704ms/step - loss: 0.0663 - accuracy: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000
# F1 Score: 1.0
